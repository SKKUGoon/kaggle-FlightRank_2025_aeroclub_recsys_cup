# %%
import sys
import os
from dotenv import load_dotenv

root_dir = os.path.abspath("..")
sys.path.append(root_dir)
dotenv_path = os.path.join(root_dir, ".env")
load_dotenv(dotenv_path)
# Out:
# True

# %%
from pathlib import Path
import math
import polars as pl
import openai
import json
import glob
import hashlib

# %%
PARQUET_PATH = os.path.join(root_dir, "data", "processed_flight_features_train.parquet")
BATCH_INPUT_JSONL = os.path.join(root_dir, "data", "batch_input.jsonl")
BATCH_DIR = os.path.join(root_dir, "data", "batch_job")
OUTPUT_DIR = os.path.join(root_dir, "data", "embedded_flight_feature.parquet")

COL_NAME = "flight_text"
MODEL_NAME = "text-embedding-3-small"

# %%
openai.api_key = os.getenv("OPENAI_API_KEY")

# %%
scan = pl.scan_parquet(PARQUET_PATH).select([COL_NAME]).with_row_index("row_id")
row_count = scan.select(pl.len()).collect(engine="streaming")[0, 0]
print(f"[INFO] Total rows: {row_count}")
# Out:
# [INFO] Total rows: 18145372

# %%
# compute chunk size
chunk_size = math.ceil(row_count / 400)
print(f"[INFO] Each file will have up to {chunk_size} rows")

for split_idx in range(360):
    start = split_idx * chunk_size
    if start >= row_count:
        break
    end = min(start + chunk_size, row_count)

    print(f"[INFO] Processing rows {start}..{end} into part {split_idx}")

    # collect this chunk
    batch_df = scan.slice(start, chunk_size).collect(streaming=True)
    texts = batch_df[COL_NAME].to_list()
    row_ids = batch_df["row_id"].to_list()

    # write to JSONL
    out_path = os.path.join(BATCH_DIR, f"batch_part_{split_idx}.jsonl")
    with open(out_path, "w", encoding="utf-8") as f:
        for rid, txt in zip(row_ids, texts):
            line = {
                "custom_id": f"row_{rid}",
                "method": "POST",
                "url": "/v1/embeddings",
                "body": {
                    "model": MODEL_NAME,
                    "input": txt
                }
            }
            f.write(json.dumps(line, ensure_ascii=False) + "\n")

    print(f"[INFO] Saved {len(row_ids)} rows to {out_path}")
# Out:
# [INFO] Each file will have up to 45364 rows
# [INFO] Processing rows 0..45364 into part 0
# /var/folders/0f/33736c396pgfbzvkb9bc8lnw0000gn/T/ipykernel_10883/2794869824.py:14: DeprecationWarning: the `streaming` parameter was deprecated in 1.25.0; use `engine` instead.
#   batch_df = scan.slice(start, chunk_size).collect(streaming=True)
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_0.jsonl
# [INFO] Processing rows 45364..90728 into part 1
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_1.jsonl
# [INFO] Processing rows 90728..136092 into part 2
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_2.jsonl
# [INFO] Processing rows 136092..181456 into part 3
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_3.jsonl
# [INFO] Processing rows 181456..226820 into part 4
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_4.jsonl
# [INFO] Processing rows 226820..272184 into part 5
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_5.jsonl
# [INFO] Processing rows 272184..317548 into part 6
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_6.jsonl
# [INFO] Processing rows 317548..362912 into part 7
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_7.jsonl
# [INFO] Processing rows 362912..408276 into part 8
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_8.jsonl
# [INFO] Processing rows 408276..453640 into part 9
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_9.jsonl
# [INFO] Processing rows 453640..499004 into part 10
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_10.jsonl
# [INFO] Processing rows 499004..544368 into part 11
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_11.jsonl
# [INFO] Processing rows 544368..589732 into part 12
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_12.jsonl
# [INFO] Processing rows 589732..635096 into part 13
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_13.jsonl
# [INFO] Processing rows 635096..680460 into part 14
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_14.jsonl
# [INFO] Processing rows 680460..725824 into part 15
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_15.jsonl
# [INFO] Processing rows 725824..771188 into part 16
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_16.jsonl
# [INFO] Processing rows 771188..816552 into part 17
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_17.jsonl
# [INFO] Processing rows 816552..861916 into part 18
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_18.jsonl
# [INFO] Processing rows 861916..907280 into part 19
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_19.jsonl
# [INFO] Processing rows 907280..952644 into part 20
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_20.jsonl
# [INFO] Processing rows 952644..998008 into part 21
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_21.jsonl
# [INFO] Processing rows 998008..1043372 into part 22
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_22.jsonl
# [INFO] Processing rows 1043372..1088736 into part 23
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_23.jsonl
# [INFO] Processing rows 1088736..1134100 into part 24
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_24.jsonl
# [INFO] Processing rows 1134100..1179464 into part 25
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_25.jsonl
# [INFO] Processing rows 1179464..1224828 into part 26
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_26.jsonl
# [INFO] Processing rows 1224828..1270192 into part 27
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_27.jsonl
# [INFO] Processing rows 1270192..1315556 into part 28
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_28.jsonl
# [INFO] Processing rows 1315556..1360920 into part 29
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_29.jsonl
# [INFO] Processing rows 1360920..1406284 into part 30
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_30.jsonl
# [INFO] Processing rows 1406284..1451648 into part 31
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_31.jsonl
# [INFO] Processing rows 1451648..1497012 into part 32
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_32.jsonl
# [INFO] Processing rows 1497012..1542376 into part 33
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_33.jsonl
# [INFO] Processing rows 1542376..1587740 into part 34
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_34.jsonl
# [INFO] Processing rows 1587740..1633104 into part 35
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_35.jsonl
# [INFO] Processing rows 1633104..1678468 into part 36
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_36.jsonl
# [INFO] Processing rows 1678468..1723832 into part 37
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_37.jsonl
# [INFO] Processing rows 1723832..1769196 into part 38
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_38.jsonl
# [INFO] Processing rows 1769196..1814560 into part 39
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_39.jsonl
# [INFO] Processing rows 1814560..1859924 into part 40
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_40.jsonl
# [INFO] Processing rows 1859924..1905288 into part 41
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_41.jsonl
# [INFO] Processing rows 1905288..1950652 into part 42
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_42.jsonl
# [INFO] Processing rows 1950652..1996016 into part 43
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_43.jsonl
# [INFO] Processing rows 1996016..2041380 into part 44
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_44.jsonl
# [INFO] Processing rows 2041380..2086744 into part 45
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_45.jsonl
# [INFO] Processing rows 2086744..2132108 into part 46
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_46.jsonl
# [INFO] Processing rows 2132108..2177472 into part 47
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_47.jsonl
# [INFO] Processing rows 2177472..2222836 into part 48
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_48.jsonl
# [INFO] Processing rows 2222836..2268200 into part 49
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_49.jsonl
# [INFO] Processing rows 2268200..2313564 into part 50
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_50.jsonl
# [INFO] Processing rows 2313564..2358928 into part 51
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_51.jsonl
# [INFO] Processing rows 2358928..2404292 into part 52
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_52.jsonl
# [INFO] Processing rows 2404292..2449656 into part 53
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_53.jsonl
# [INFO] Processing rows 2449656..2495020 into part 54
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_54.jsonl
# [INFO] Processing rows 2495020..2540384 into part 55
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_55.jsonl
# [INFO] Processing rows 2540384..2585748 into part 56
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_56.jsonl
# [INFO] Processing rows 2585748..2631112 into part 57
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_57.jsonl
# [INFO] Processing rows 2631112..2676476 into part 58
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_58.jsonl
# [INFO] Processing rows 2676476..2721840 into part 59
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_59.jsonl
# [INFO] Processing rows 2721840..2767204 into part 60
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_60.jsonl
# [INFO] Processing rows 2767204..2812568 into part 61
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_61.jsonl
# [INFO] Processing rows 2812568..2857932 into part 62
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_62.jsonl
# [INFO] Processing rows 2857932..2903296 into part 63
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_63.jsonl
# [INFO] Processing rows 2903296..2948660 into part 64
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_64.jsonl
# [INFO] Processing rows 2948660..2994024 into part 65
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_65.jsonl
# [INFO] Processing rows 2994024..3039388 into part 66
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_66.jsonl
# [INFO] Processing rows 3039388..3084752 into part 67
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_67.jsonl
# [INFO] Processing rows 3084752..3130116 into part 68
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_68.jsonl
# [INFO] Processing rows 3130116..3175480 into part 69
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_69.jsonl
# [INFO] Processing rows 3175480..3220844 into part 70
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_70.jsonl
# [INFO] Processing rows 3220844..3266208 into part 71
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_71.jsonl
# [INFO] Processing rows 3266208..3311572 into part 72
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_72.jsonl
# [INFO] Processing rows 3311572..3356936 into part 73
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_73.jsonl
# [INFO] Processing rows 3356936..3402300 into part 74
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_74.jsonl
# [INFO] Processing rows 3402300..3447664 into part 75
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_75.jsonl
# [INFO] Processing rows 3447664..3493028 into part 76
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_76.jsonl
# [INFO] Processing rows 3493028..3538392 into part 77
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_77.jsonl
# [INFO] Processing rows 3538392..3583756 into part 78
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_78.jsonl
# [INFO] Processing rows 3583756..3629120 into part 79
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_79.jsonl
# [INFO] Processing rows 3629120..3674484 into part 80
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_80.jsonl
# [INFO] Processing rows 3674484..3719848 into part 81
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_81.jsonl
# [INFO] Processing rows 3719848..3765212 into part 82
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_82.jsonl
# [INFO] Processing rows 3765212..3810576 into part 83
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_83.jsonl
# [INFO] Processing rows 3810576..3855940 into part 84
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_84.jsonl
# [INFO] Processing rows 3855940..3901304 into part 85
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_85.jsonl
# [INFO] Processing rows 3901304..3946668 into part 86
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_86.jsonl
# [INFO] Processing rows 3946668..3992032 into part 87
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_87.jsonl
# [INFO] Processing rows 3992032..4037396 into part 88
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_88.jsonl
# [INFO] Processing rows 4037396..4082760 into part 89
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_89.jsonl
# [INFO] Processing rows 4082760..4128124 into part 90
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_90.jsonl
# [INFO] Processing rows 4128124..4173488 into part 91
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_91.jsonl
# [INFO] Processing rows 4173488..4218852 into part 92
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_92.jsonl
# [INFO] Processing rows 4218852..4264216 into part 93
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_93.jsonl
# [INFO] Processing rows 4264216..4309580 into part 94
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_94.jsonl
# [INFO] Processing rows 4309580..4354944 into part 95
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_95.jsonl
# [INFO] Processing rows 4354944..4400308 into part 96
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_96.jsonl
# [INFO] Processing rows 4400308..4445672 into part 97
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_97.jsonl
# [INFO] Processing rows 4445672..4491036 into part 98
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_98.jsonl
# [INFO] Processing rows 4491036..4536400 into part 99
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_99.jsonl
# [INFO] Processing rows 4536400..4581764 into part 100
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_100.jsonl
# [INFO] Processing rows 4581764..4627128 into part 101
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_101.jsonl
# [INFO] Processing rows 4627128..4672492 into part 102
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_102.jsonl
# [INFO] Processing rows 4672492..4717856 into part 103
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_103.jsonl
# [INFO] Processing rows 4717856..4763220 into part 104
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_104.jsonl
# [INFO] Processing rows 4763220..4808584 into part 105
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_105.jsonl
# [INFO] Processing rows 4808584..4853948 into part 106
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_106.jsonl
# [INFO] Processing rows 4853948..4899312 into part 107
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_107.jsonl
# [INFO] Processing rows 4899312..4944676 into part 108
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_108.jsonl
# [INFO] Processing rows 4944676..4990040 into part 109
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_109.jsonl
# [INFO] Processing rows 4990040..5035404 into part 110
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_110.jsonl
# [INFO] Processing rows 5035404..5080768 into part 111
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_111.jsonl
# [INFO] Processing rows 5080768..5126132 into part 112
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_112.jsonl
# [INFO] Processing rows 5126132..5171496 into part 113
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_113.jsonl
# [INFO] Processing rows 5171496..5216860 into part 114
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_114.jsonl
# [INFO] Processing rows 5216860..5262224 into part 115
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_115.jsonl
# [INFO] Processing rows 5262224..5307588 into part 116
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_116.jsonl
# [INFO] Processing rows 5307588..5352952 into part 117
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_117.jsonl
# [INFO] Processing rows 5352952..5398316 into part 118
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_118.jsonl
# [INFO] Processing rows 5398316..5443680 into part 119
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_119.jsonl
# [INFO] Processing rows 5443680..5489044 into part 120
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_120.jsonl
# [INFO] Processing rows 5489044..5534408 into part 121
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_121.jsonl
# [INFO] Processing rows 5534408..5579772 into part 122
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_122.jsonl
# [INFO] Processing rows 5579772..5625136 into part 123
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_123.jsonl
# [INFO] Processing rows 5625136..5670500 into part 124
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_124.jsonl
# [INFO] Processing rows 5670500..5715864 into part 125
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_125.jsonl
# [INFO] Processing rows 5715864..5761228 into part 126
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_126.jsonl
# [INFO] Processing rows 5761228..5806592 into part 127
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_127.jsonl
# [INFO] Processing rows 5806592..5851956 into part 128
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_128.jsonl
# [INFO] Processing rows 5851956..5897320 into part 129
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_129.jsonl
# [INFO] Processing rows 5897320..5942684 into part 130
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_130.jsonl
# [INFO] Processing rows 5942684..5988048 into part 131
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_131.jsonl
# [INFO] Processing rows 5988048..6033412 into part 132
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_132.jsonl
# [INFO] Processing rows 6033412..6078776 into part 133
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_133.jsonl
# [INFO] Processing rows 6078776..6124140 into part 134
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_134.jsonl
# [INFO] Processing rows 6124140..6169504 into part 135
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_135.jsonl
# [INFO] Processing rows 6169504..6214868 into part 136
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_136.jsonl
# [INFO] Processing rows 6214868..6260232 into part 137
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_137.jsonl
# [INFO] Processing rows 6260232..6305596 into part 138
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_138.jsonl
# [INFO] Processing rows 6305596..6350960 into part 139
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_139.jsonl
# [INFO] Processing rows 6350960..6396324 into part 140
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_140.jsonl
# [INFO] Processing rows 6396324..6441688 into part 141
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_141.jsonl
# [INFO] Processing rows 6441688..6487052 into part 142
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_142.jsonl
# [INFO] Processing rows 6487052..6532416 into part 143
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_143.jsonl
# [INFO] Processing rows 6532416..6577780 into part 144
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_144.jsonl
# [INFO] Processing rows 6577780..6623144 into part 145
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_145.jsonl
# [INFO] Processing rows 6623144..6668508 into part 146
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_146.jsonl
# [INFO] Processing rows 6668508..6713872 into part 147
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_147.jsonl
# [INFO] Processing rows 6713872..6759236 into part 148
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_148.jsonl
# [INFO] Processing rows 6759236..6804600 into part 149
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_149.jsonl
# [INFO] Processing rows 6804600..6849964 into part 150
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_150.jsonl
# [INFO] Processing rows 6849964..6895328 into part 151
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_151.jsonl
# [INFO] Processing rows 6895328..6940692 into part 152
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_152.jsonl
# [INFO] Processing rows 6940692..6986056 into part 153
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_153.jsonl
# [INFO] Processing rows 6986056..7031420 into part 154
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_154.jsonl
# [INFO] Processing rows 7031420..7076784 into part 155
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_155.jsonl
# [INFO] Processing rows 7076784..7122148 into part 156
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_156.jsonl
# [INFO] Processing rows 7122148..7167512 into part 157
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_157.jsonl
# [INFO] Processing rows 7167512..7212876 into part 158
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_158.jsonl
# [INFO] Processing rows 7212876..7258240 into part 159
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_159.jsonl
# [INFO] Processing rows 7258240..7303604 into part 160
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_160.jsonl
# [INFO] Processing rows 7303604..7348968 into part 161
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_161.jsonl
# [INFO] Processing rows 7348968..7394332 into part 162
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_162.jsonl
# [INFO] Processing rows 7394332..7439696 into part 163
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_163.jsonl
# [INFO] Processing rows 7439696..7485060 into part 164
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_164.jsonl
# [INFO] Processing rows 7485060..7530424 into part 165
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_165.jsonl
# [INFO] Processing rows 7530424..7575788 into part 166
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_166.jsonl
# [INFO] Processing rows 7575788..7621152 into part 167
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_167.jsonl
# [INFO] Processing rows 7621152..7666516 into part 168
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_168.jsonl
# [INFO] Processing rows 7666516..7711880 into part 169
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_169.jsonl
# [INFO] Processing rows 7711880..7757244 into part 170
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_170.jsonl
# [INFO] Processing rows 7757244..7802608 into part 171
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_171.jsonl
# [INFO] Processing rows 7802608..7847972 into part 172
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_172.jsonl
# [INFO] Processing rows 7847972..7893336 into part 173
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_173.jsonl
# [INFO] Processing rows 7893336..7938700 into part 174
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_174.jsonl
# [INFO] Processing rows 7938700..7984064 into part 175
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_175.jsonl
# [INFO] Processing rows 7984064..8029428 into part 176
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_176.jsonl
# [INFO] Processing rows 8029428..8074792 into part 177
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_177.jsonl
# [INFO] Processing rows 8074792..8120156 into part 178
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_178.jsonl
# [INFO] Processing rows 8120156..8165520 into part 179
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_179.jsonl
# [INFO] Processing rows 8165520..8210884 into part 180
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_180.jsonl
# [INFO] Processing rows 8210884..8256248 into part 181
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_181.jsonl
# [INFO] Processing rows 8256248..8301612 into part 182
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_182.jsonl
# [INFO] Processing rows 8301612..8346976 into part 183
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_183.jsonl
# [INFO] Processing rows 8346976..8392340 into part 184
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_184.jsonl
# [INFO] Processing rows 8392340..8437704 into part 185
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_185.jsonl
# [INFO] Processing rows 8437704..8483068 into part 186
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_186.jsonl
# [INFO] Processing rows 8483068..8528432 into part 187
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_187.jsonl
# [INFO] Processing rows 8528432..8573796 into part 188
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_188.jsonl
# [INFO] Processing rows 8573796..8619160 into part 189
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_189.jsonl
# [INFO] Processing rows 8619160..8664524 into part 190
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_190.jsonl
# [INFO] Processing rows 8664524..8709888 into part 191
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_191.jsonl
# [INFO] Processing rows 8709888..8755252 into part 192
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_192.jsonl
# [INFO] Processing rows 8755252..8800616 into part 193
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_193.jsonl
# [INFO] Processing rows 8800616..8845980 into part 194
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_194.jsonl
# [INFO] Processing rows 8845980..8891344 into part 195
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_195.jsonl
# [INFO] Processing rows 8891344..8936708 into part 196
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_196.jsonl
# [INFO] Processing rows 8936708..8982072 into part 197
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_197.jsonl
# [INFO] Processing rows 8982072..9027436 into part 198
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_198.jsonl
# [INFO] Processing rows 9027436..9072800 into part 199
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_199.jsonl
# [INFO] Processing rows 9072800..9118164 into part 200
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_200.jsonl
# [INFO] Processing rows 9118164..9163528 into part 201
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_201.jsonl
# [INFO] Processing rows 9163528..9208892 into part 202
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_202.jsonl
# [INFO] Processing rows 9208892..9254256 into part 203
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_203.jsonl
# [INFO] Processing rows 9254256..9299620 into part 204
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_204.jsonl
# [INFO] Processing rows 9299620..9344984 into part 205
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_205.jsonl
# [INFO] Processing rows 9344984..9390348 into part 206
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_206.jsonl
# [INFO] Processing rows 9390348..9435712 into part 207
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_207.jsonl
# [INFO] Processing rows 9435712..9481076 into part 208
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_208.jsonl
# [INFO] Processing rows 9481076..9526440 into part 209
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_209.jsonl
# [INFO] Processing rows 9526440..9571804 into part 210
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_210.jsonl
# [INFO] Processing rows 9571804..9617168 into part 211
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_211.jsonl
# [INFO] Processing rows 9617168..9662532 into part 212
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_212.jsonl
# [INFO] Processing rows 9662532..9707896 into part 213
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_213.jsonl
# [INFO] Processing rows 9707896..9753260 into part 214
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_214.jsonl
# [INFO] Processing rows 9753260..9798624 into part 215
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_215.jsonl
# [INFO] Processing rows 9798624..9843988 into part 216
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_216.jsonl
# [INFO] Processing rows 9843988..9889352 into part 217
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_217.jsonl
# [INFO] Processing rows 9889352..9934716 into part 218
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_218.jsonl
# [INFO] Processing rows 9934716..9980080 into part 219
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_219.jsonl
# [INFO] Processing rows 9980080..10025444 into part 220
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_220.jsonl
# [INFO] Processing rows 10025444..10070808 into part 221
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_221.jsonl
# [INFO] Processing rows 10070808..10116172 into part 222
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_222.jsonl
# [INFO] Processing rows 10116172..10161536 into part 223
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_223.jsonl
# [INFO] Processing rows 10161536..10206900 into part 224
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_224.jsonl
# [INFO] Processing rows 10206900..10252264 into part 225
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_225.jsonl
# [INFO] Processing rows 10252264..10297628 into part 226
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_226.jsonl
# [INFO] Processing rows 10297628..10342992 into part 227
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_227.jsonl
# [INFO] Processing rows 10342992..10388356 into part 228
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_228.jsonl
# [INFO] Processing rows 10388356..10433720 into part 229
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_229.jsonl
# [INFO] Processing rows 10433720..10479084 into part 230
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_230.jsonl
# [INFO] Processing rows 10479084..10524448 into part 231
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_231.jsonl
# [INFO] Processing rows 10524448..10569812 into part 232
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_232.jsonl
# [INFO] Processing rows 10569812..10615176 into part 233
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_233.jsonl
# [INFO] Processing rows 10615176..10660540 into part 234
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_234.jsonl
# [INFO] Processing rows 10660540..10705904 into part 235
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_235.jsonl
# [INFO] Processing rows 10705904..10751268 into part 236
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_236.jsonl
# [INFO] Processing rows 10751268..10796632 into part 237
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_237.jsonl
# [INFO] Processing rows 10796632..10841996 into part 238
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_238.jsonl
# [INFO] Processing rows 10841996..10887360 into part 239
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_239.jsonl
# [INFO] Processing rows 10887360..10932724 into part 240
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_240.jsonl
# [INFO] Processing rows 10932724..10978088 into part 241
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_241.jsonl
# [INFO] Processing rows 10978088..11023452 into part 242
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_242.jsonl
# [INFO] Processing rows 11023452..11068816 into part 243
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_243.jsonl
# [INFO] Processing rows 11068816..11114180 into part 244
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_244.jsonl
# [INFO] Processing rows 11114180..11159544 into part 245
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_245.jsonl
# [INFO] Processing rows 11159544..11204908 into part 246
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_246.jsonl
# [INFO] Processing rows 11204908..11250272 into part 247
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_247.jsonl
# [INFO] Processing rows 11250272..11295636 into part 248
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_248.jsonl
# [INFO] Processing rows 11295636..11341000 into part 249
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_249.jsonl
# [INFO] Processing rows 11341000..11386364 into part 250
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_250.jsonl
# [INFO] Processing rows 11386364..11431728 into part 251
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_251.jsonl
# [INFO] Processing rows 11431728..11477092 into part 252
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_252.jsonl
# [INFO] Processing rows 11477092..11522456 into part 253
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_253.jsonl
# [INFO] Processing rows 11522456..11567820 into part 254
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_254.jsonl
# [INFO] Processing rows 11567820..11613184 into part 255
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_255.jsonl
# [INFO] Processing rows 11613184..11658548 into part 256
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_256.jsonl
# [INFO] Processing rows 11658548..11703912 into part 257
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_257.jsonl
# [INFO] Processing rows 11703912..11749276 into part 258
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_258.jsonl
# [INFO] Processing rows 11749276..11794640 into part 259
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_259.jsonl
# [INFO] Processing rows 11794640..11840004 into part 260
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_260.jsonl
# [INFO] Processing rows 11840004..11885368 into part 261
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_261.jsonl
# [INFO] Processing rows 11885368..11930732 into part 262
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_262.jsonl
# [INFO] Processing rows 11930732..11976096 into part 263
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_263.jsonl
# [INFO] Processing rows 11976096..12021460 into part 264
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_264.jsonl
# [INFO] Processing rows 12021460..12066824 into part 265
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_265.jsonl
# [INFO] Processing rows 12066824..12112188 into part 266
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_266.jsonl
# [INFO] Processing rows 12112188..12157552 into part 267
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_267.jsonl
# [INFO] Processing rows 12157552..12202916 into part 268
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_268.jsonl
# [INFO] Processing rows 12202916..12248280 into part 269
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_269.jsonl
# [INFO] Processing rows 12248280..12293644 into part 270
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_270.jsonl
# [INFO] Processing rows 12293644..12339008 into part 271
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_271.jsonl
# [INFO] Processing rows 12339008..12384372 into part 272
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_272.jsonl
# [INFO] Processing rows 12384372..12429736 into part 273
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_273.jsonl
# [INFO] Processing rows 12429736..12475100 into part 274
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_274.jsonl
# [INFO] Processing rows 12475100..12520464 into part 275
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_275.jsonl
# [INFO] Processing rows 12520464..12565828 into part 276
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_276.jsonl
# [INFO] Processing rows 12565828..12611192 into part 277
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_277.jsonl
# [INFO] Processing rows 12611192..12656556 into part 278
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_278.jsonl
# [INFO] Processing rows 12656556..12701920 into part 279
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_279.jsonl
# [INFO] Processing rows 12701920..12747284 into part 280
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_280.jsonl
# [INFO] Processing rows 12747284..12792648 into part 281
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_281.jsonl
# [INFO] Processing rows 12792648..12838012 into part 282
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_282.jsonl
# [INFO] Processing rows 12838012..12883376 into part 283
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_283.jsonl
# [INFO] Processing rows 12883376..12928740 into part 284
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_284.jsonl
# [INFO] Processing rows 12928740..12974104 into part 285
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_285.jsonl
# [INFO] Processing rows 12974104..13019468 into part 286
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_286.jsonl
# [INFO] Processing rows 13019468..13064832 into part 287
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_287.jsonl
# [INFO] Processing rows 13064832..13110196 into part 288
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_288.jsonl
# [INFO] Processing rows 13110196..13155560 into part 289
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_289.jsonl
# [INFO] Processing rows 13155560..13200924 into part 290
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_290.jsonl
# [INFO] Processing rows 13200924..13246288 into part 291
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_291.jsonl
# [INFO] Processing rows 13246288..13291652 into part 292
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_292.jsonl
# [INFO] Processing rows 13291652..13337016 into part 293
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_293.jsonl
# [INFO] Processing rows 13337016..13382380 into part 294
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_294.jsonl
# [INFO] Processing rows 13382380..13427744 into part 295
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_295.jsonl
# [INFO] Processing rows 13427744..13473108 into part 296
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_296.jsonl
# [INFO] Processing rows 13473108..13518472 into part 297
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_297.jsonl
# [INFO] Processing rows 13518472..13563836 into part 298
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_298.jsonl
# [INFO] Processing rows 13563836..13609200 into part 299
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_299.jsonl
# [INFO] Processing rows 13609200..13654564 into part 300
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_300.jsonl
# [INFO] Processing rows 13654564..13699928 into part 301
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_301.jsonl
# [INFO] Processing rows 13699928..13745292 into part 302
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_302.jsonl
# [INFO] Processing rows 13745292..13790656 into part 303
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_303.jsonl
# [INFO] Processing rows 13790656..13836020 into part 304
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_304.jsonl
# [INFO] Processing rows 13836020..13881384 into part 305
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_305.jsonl
# [INFO] Processing rows 13881384..13926748 into part 306
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_306.jsonl
# [INFO] Processing rows 13926748..13972112 into part 307
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_307.jsonl
# [INFO] Processing rows 13972112..14017476 into part 308
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_308.jsonl
# [INFO] Processing rows 14017476..14062840 into part 309
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_309.jsonl
# [INFO] Processing rows 14062840..14108204 into part 310
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_310.jsonl
# [INFO] Processing rows 14108204..14153568 into part 311
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_311.jsonl
# [INFO] Processing rows 14153568..14198932 into part 312
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_312.jsonl
# [INFO] Processing rows 14198932..14244296 into part 313
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_313.jsonl
# [INFO] Processing rows 14244296..14289660 into part 314
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_314.jsonl
# [INFO] Processing rows 14289660..14335024 into part 315
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_315.jsonl
# [INFO] Processing rows 14335024..14380388 into part 316
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_316.jsonl
# [INFO] Processing rows 14380388..14425752 into part 317
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_317.jsonl
# [INFO] Processing rows 14425752..14471116 into part 318
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_318.jsonl
# [INFO] Processing rows 14471116..14516480 into part 319
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_319.jsonl
# [INFO] Processing rows 14516480..14561844 into part 320
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_320.jsonl
# [INFO] Processing rows 14561844..14607208 into part 321
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_321.jsonl
# [INFO] Processing rows 14607208..14652572 into part 322
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_322.jsonl
# [INFO] Processing rows 14652572..14697936 into part 323
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_323.jsonl
# [INFO] Processing rows 14697936..14743300 into part 324
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_324.jsonl
# [INFO] Processing rows 14743300..14788664 into part 325
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_325.jsonl
# [INFO] Processing rows 14788664..14834028 into part 326
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_326.jsonl
# [INFO] Processing rows 14834028..14879392 into part 327
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_327.jsonl
# [INFO] Processing rows 14879392..14924756 into part 328
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_328.jsonl
# [INFO] Processing rows 14924756..14970120 into part 329
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_329.jsonl
# [INFO] Processing rows 14970120..15015484 into part 330
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_330.jsonl
# [INFO] Processing rows 15015484..15060848 into part 331
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_331.jsonl
# [INFO] Processing rows 15060848..15106212 into part 332
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_332.jsonl
# [INFO] Processing rows 15106212..15151576 into part 333
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_333.jsonl
# [INFO] Processing rows 15151576..15196940 into part 334
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_334.jsonl
# [INFO] Processing rows 15196940..15242304 into part 335
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_335.jsonl
# [INFO] Processing rows 15242304..15287668 into part 336
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_336.jsonl
# [INFO] Processing rows 15287668..15333032 into part 337
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_337.jsonl
# [INFO] Processing rows 15333032..15378396 into part 338
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_338.jsonl
# [INFO] Processing rows 15378396..15423760 into part 339
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_339.jsonl
# [INFO] Processing rows 15423760..15469124 into part 340
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_340.jsonl
# [INFO] Processing rows 15469124..15514488 into part 341
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_341.jsonl
# [INFO] Processing rows 15514488..15559852 into part 342
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_342.jsonl
# [INFO] Processing rows 15559852..15605216 into part 343
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_343.jsonl
# [INFO] Processing rows 15605216..15650580 into part 344
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_344.jsonl
# [INFO] Processing rows 15650580..15695944 into part 345
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_345.jsonl
# [INFO] Processing rows 15695944..15741308 into part 346
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_346.jsonl
# [INFO] Processing rows 15741308..15786672 into part 347
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_347.jsonl
# [INFO] Processing rows 15786672..15832036 into part 348
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_348.jsonl
# [INFO] Processing rows 15832036..15877400 into part 349
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_349.jsonl
# [INFO] Processing rows 15877400..15922764 into part 350
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_350.jsonl
# [INFO] Processing rows 15922764..15968128 into part 351
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_351.jsonl
# [INFO] Processing rows 15968128..16013492 into part 352
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_352.jsonl
# [INFO] Processing rows 16013492..16058856 into part 353
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_353.jsonl
# [INFO] Processing rows 16058856..16104220 into part 354
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_354.jsonl
# [INFO] Processing rows 16104220..16149584 into part 355
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_355.jsonl
# [INFO] Processing rows 16149584..16194948 into part 356
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_356.jsonl
# [INFO] Processing rows 16194948..16240312 into part 357
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_357.jsonl
# [INFO] Processing rows 16240312..16285676 into part 358
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_358.jsonl
# [INFO] Processing rows 16285676..16331040 into part 359
# [INFO] Saved 45364 rows to /Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_359.jsonl

# %%
# Upload JSONL as batch file
client = openai.OpenAI()

# Directory where you stored your chunked JSONL files
CHUNK_PATTERN = os.path.join(BATCH_DIR, "batch_part_*.jsonl")

# Get all chunk files (sorted to keep track)
chunk_files = sorted(glob.glob(CHUNK_PATTERN))

# %%
chunk_files[:10]
# Out:
# ['/Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_0.jsonl',
#  '/Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_1.jsonl',
#  '/Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_10.jsonl',
#  '/Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_100.jsonl',
#  '/Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_101.jsonl',
#  '/Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_102.jsonl',
#  '/Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_103.jsonl',
#  '/Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_104.jsonl',
#  '/Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_105.jsonl',
#  '/Users/goonzard/Developer/data-science-09-kaggle-airplane/data/batch_job/batch_part_106.jsonl']

# %%
class BatchEmbed:
    def __init__(self, jsonl_files, output_path: str | Path, file_tag: str):
        """
        jsonl_files: list of up to 10 paths to your JSONL input files
        """
        if len(jsonl_files) > 10:
            raise ValueError("You can only handle up to 10 files per batch wave.")
        self.jsonl_files = jsonl_files
        
        # Internal memory
        self.file_ids = []   # will hold OpenAI file IDs after send()
        self.batch_ids = []  # will hold OpenAI batch IDs after batch()
        
        # Client
        self.client = openai.OpenAI()
        
        # Save
        self.output_path = output_path
        self.file_tag = file_tag

    def send(self):
        """Upload all JSONL files and save file IDs."""
        for path in self.jsonl_files:
            with open(path, "rb") as f:
                uploaded = self.client.files.create(file=f, purpose="batch")
                self.file_ids.append(uploaded.id)
                print(f"[INFO] Uploaded {path} → file_id: {uploaded.id}")
        print("[INFO] All file_ids:", self.file_ids)

    def manual_file_id_insert(self, *file_ids):
        self.file_ids = file_ids

    def batch(self):
        """Create batch jobs from uploaded file IDs."""
        if not self.file_ids:
            raise RuntimeError("No file_ids found. Run send() first.")
        for idx, fid in enumerate(self.file_ids):
            batch = self.client.batches.create(
                input_file_id=fid,
                endpoint="/v1/embeddings",
                completion_window="24h",
                metadata={"description": f"flight embeddings job part {idx}"}
            )
            self.batch_ids.append(batch.id)
            print(f"[INFO] Created batch job for file_id {fid} → batch_id: {batch.id}")
        print("[INFO] All batch_ids:", self.batch_ids)

    def manual_batch_id_insert(self, *batch_ids):
        self.batch_ids = batch_ids

    def retrieve(self):
        """
        Retrieve results for each completed batch and write to parquet.
        Run only after you confirm via dashboard that all batch_ids are completed.
        """
        os.makedirs(self.output_path, exist_ok=True)
        if not self.batch_ids:
            raise RuntimeError("No batch_ids found. Run batch() first.")

        all_rows, all_embs = [], []
        for bid in self.batch_ids:
            status = self.client.batches.retrieve(bid)
            if status.status != "completed":
                print(f"[WARN] Batch {bid} not completed (status={status.status}), skipping.")
                continue
            output_file_id = status.output_file_id
            print(f"[INFO] Retrieving output for batch_id {bid}")

            output_content = self.client.files.content(output_file_id)

            # parse lines
            for line in output_content.iter_lines():
                if not line:
                    continue
                data = json.loads(line)
                if data.get("error"):
                    continue
                rid = int(data["custom_id"].replace("row_", ""))
                emb = data["response"]["body"]["data"][0]["embedding"]
                all_rows.append(rid)
                all_embs.append(emb)

        if not all_embs:
            print("[WARN] No embeddings found in any batch.")
            return

        # build one merged dataframe
        emb_cols = {f"emb_{j}": [v[j] for v in all_embs] for j in range(len(all_embs[0]))}
        df = pl.DataFrame({"row_id": all_rows, **emb_cols}).sort("row_id")

        out_path = os.path.join(self.output_path, f"embeddings_{self.file_tag}.parquet")
        df.write_parquet(out_path)
        print(f"[INFO] Saved merged parquet with {len(all_rows)} rows → {out_path}")

# %%
# Create object
START, END = 10, 20
FILE_TAG = hashlib.sha256(f"{START}_{END}".encode()).hexdigest()

embedder = BatchEmbed(chunk_files[START:END], OUTPUT_DIR, FILE_TAG)

# 1️⃣ Upload files
# embedder.send()  
# 👉 Save/backup printed file_ids somewhere safe

# 2️⃣ Start batch jobs
# embedder.batch()
# 👉 Save/backup printed batch_ids somewhere safe

# 3️⃣ Later, after confirming completion in OpenAI dashboard:
# embedder.retrieve()

# %%
# First batch usage
START, END = 0, 10
FILE_TAG = hashlib.sha256(f"{START}_{END}".encode()).hexdigest()
embedder = BatchEmbed([], OUTPUT_DIR, FILE_TAG)

embedder.manual_batch_id_insert(
    "batch_687deaf1221881909a54e7f29c9a4ea7",
    "batch_687deae736648190b90313d7c362920a",
    "batch_687deade9e908190b72ccea7b1d3e551",
    "batch_687dead3b3a88190a9af44ab66e65a8d",
    "batch_687deacaabe08190b338c5db0bf26e75",
    "batch_687deabfc11881909545df5bfa6d5a90",
    "batch_687deab3db74819080aaf944aa255d53",
    "batch_687deaab1aec8190abf09cb13acb5756",
    "batch_687deaa275e08190a29f67bf9c9cb4be",
    "batch_687dea91e1c481908202a9c930b91dd1"
)
embedder.retrieve()

# %% [markdown]
# ### Engineering Job Record
#
# | Batch Start, End | Start DT | End DT |
# |------------------|----------|--------|
# |0, 10| 25/07/21 16:20 | 25/07/21 18:00 |
# |10, 20 |

# %% [markdown]
# ## Optional - Embedding with HuggingFace Qwen
#
# * Couldn't accomplish this with my Mac
#
# ```python
# # Config
# PARQUET_PATH = os.path.join(root_dir, "data", "processed_flight_features_train.parquet")
# OUTPUT_DIR = os.path.join(root_dir, "data", "embed")
# BATCH_SIZE = 32
# CHUNK_SIZE = 8192
# DEVICE = "mps"
# COL_NAME = "flight_text"
# MODEL = "Qwen/Qwen3-Embedding-0.6B"
#
# # Load the model
# model = SentenceTransformer(MODEL)
# model.to(torch.device(DEVICE))  # move model to Apple GPU
#
# scan = pl.scan_parquet(PARQUET_PATH).select([COL_NAME])
# row_count = scan.select(pl.len()).collect(engine="streaming")[0, 0]
# print(f"[INFO] Total rows: {row_count}")
#
# for start in range(0, row_count, CHUNK_SIZE):
#     print(f"[INFO] Processing rows {start}..{min(start+CHUNK_SIZE, row_count)}")
#
#     # load a chunk from parquet
#     batch_df = scan.slice(start, CHUNK_SIZE).collect(engine="streaming")
#     texts = batch_df.get_column(COL_NAME).to_list()
#     del batch_df  # free as soon as possible
#
#     # ✅ embed with no_grad to save memory
#     with torch.no_grad():
#         embeddings = model.encode(
#             texts,
#             batch_size=BATCH_SIZE,
#             device=DEVICE,
#             convert_to_tensor=True,
#             show_progress_bar=True,
#             normalize_embeddings=True,
#         )
#
#     # ✅ save and release GPU memory immediately
#     np.save(os.path.join(OUTPUT_DIR, f"embeddings_part_{start//CHUNK_SIZE}.npy"),
#             embeddings.cpu().numpy())
#     print(f"[INFO] Saved part {start//CHUNK_SIZE}")
#
#     # ✅ release references and clear MPS cache
#     del texts
#     del embeddings
#     torch.mps.empty_cache()
#
# print("[✅] All done.")
# ```
